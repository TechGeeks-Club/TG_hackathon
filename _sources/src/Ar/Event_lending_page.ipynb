# %% [markdown]
# <div dir="rtl" align="right">
#
# # 1-صفحة الهبوط:
#
# </div>
# ___
#
# ```{div} sd-sphinx-override sd-btn sd-text-wrap lang
# غير اللغة
# ```

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 1-مقدمة - لمحة عامة عن المشروع
# يتضمن هذا المشروع إنشاء صفحة مقصودة لحدث (مؤتمر، ورش عمل، إلخ) للترويج للحدث، وتوفير المعلومات للمستخدمين، والسماح بالتسجيل أو حتى شراء التذاكر.
#
# والهدف من ذلك هو تحسين المهارات في بناء الواجهات الأمامية والخلفية وتصميم UX/ UI وإدارة قواعد البيانات مع إنشاء منتج وظيفي وجمالي.
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2-الجمهور المستهدف
#
# -**المستخدمون النهائيون:** الأشخاص المهتمون بالحدث (الحضور والمعجبون والمحترفون).
#
#
# -**العميل:** منظم الحدث (لتعزيز وإدارة التسجيلات).
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3.	الخصائص الرئيسية
# 1.	الواجهة الأمامية: - صفحة ويب مع مؤقت العد التنازلي باستخدام JavaScript للحدث. - أقسام الجدول الزمني، والمتحدثين/فناني الأداء، والرعاة. نموذج التسجيل مع التحقق من الصحة الميدانية.
# 2.	تصميم UX/ UI: - تصميم حديث وسريع الاستجابة. - رسوم متحركة بسيطة (animations) لتعزيز تجربة المستخدم.
#
# 3.	الخلفية: - إدارة التسجيل من خلال نموذج استمارة. - محاكاة نظام الدفع.
#
# 4.	قاعدة البيانات: - تخزين معلومات المشاركين (الاسم والبريد الإلكتروني ونوع التذكرة).
#
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 4.	النواتج المنتظرة
# 1.	الواجهة الأمامية
#
# قم بإنشاء صفحة ويب بسيطة وسريعة الاستجابة باستخدام: - نموذج (الاسم والبريد الإلكتروني وما إلى ذلك).  - التصميم الأساسي (الألوان والخطوط والتخطيط).  - رسالة تأكيد بعد تقديم النموذج.
#
#
# **1.	تصميم UX/ UI:** - نموذج Figma للصفحة المقصودة. - لوحة ألوان محددة والطباعة.
# **2.	الواجهة الخلفية:** - نموذج وظيفي يرسل البيانات إلى قاعدة بيانات. - رسالة تأكيد بعد التسجيل.
#
# **3.	قاعدة البيانات**: - بنية قاعدة البيانات (مخطط SQL أو نموذج MongoDB).  - بيانات المشاركين المخزنة والمتاحة.
#
# **4.	الوثائق**: -  ملف Readme.md يشرح كيفية تثبيت المشروع واستخدامه. - تعليقات المدونة لشرح الوظائف.
#
# ## 5.	القيود - اختياري - اعتمادا على المشروع
#
# التوافق مع المتصفحات الحديثة (Chrome و Firefox و Edge).
#
#
# أمان البيانات (التحقق من صحة الحقل، تشفير كلمة المرور).
#
#
# </div>
