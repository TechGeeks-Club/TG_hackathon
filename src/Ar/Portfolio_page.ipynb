# %% [markdown]
# <div dir="rtl" align="right">
#
# #  مشروع صفحة الحافة
#
# </div>
#
# ___
#
# ```{div} sd-sphinx-override sd-btn sd-text-wrap lang
# غير اللغة
# ```

# %% [markdown]
# <div dir="rtl" align="right">
#
# ##  مقدمة - نظرة عامة على المشروع:
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# كجزء من التعاون، نود أن نكلف فريقا بإنشاء محفظة عبر الإنترنت تلبي احتياجاتنا المهنية.  وستكون هذه المحفظة بمثابة عرض لإنجازاتنا ومهاراتنا وخدماتنا بطريقة جذابة وتفاعلية.
#
# والهدف من ذلك هو تمكين الفريق من وضع مهاراتهم في تطوير الويب والتصميم موضع التنفيذ، أثناء العمل على مشروع ملموس.  يجب أن تكون المحفظة مريحة وسريعة الاستجابة وتعكس هوية بصرية تتوافق مع أعمالنا.
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2.الجمهور المستهدف:
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# **الجمهور الأساسي:**  العملاء المحتملين الذين يسعون إلى فهم خبراتنا وخدماتنا.
#
# **الجمهور الثانوي:**  شركاء الأعمال والتوظيف المهتمين بخلفيتنا المهنية وإنجازاتنا.
#
# يجب أن تكون المحفظة مصممة لجذب هؤلاء الجماهير من خلال التواصل بوضوح مع عروض القيمة الخاصة بنا وعرض عملنا بفعالية.
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3 - السمات الرئيسية:
#
# يجب أن تتضمن المحفظة الخصائص التالية
#
# -**التصميم الحديث والمهني:**  واجهة نظيفة وجذابة بصريا.
#
#
# -**الملاحة بديهية:**  تجربة المستخدم السائل مع تسلسل هرمي واضح من المعلومات.
#
#
# -**معرض المشروع:**  العرض التفاعلي لمشاريعنا مع الأوصاف والصور.
#
#
# -**نموذج الاتصال:**  تمكين الزوار من الاتصال بنا بسهولة.
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 4 - المنجزات المستهدفة:
# موقع ويب محفظة وظيفية مستضاف عبر الإنترنت.
#
#
# تصميم قابل للإدارة واستجابة.
#
#
# عرض تقديمي للمشروع يوضح بالتفصيل الخيارات التقنية والرسوم البيانية.
#
#
# هوية بصرية مقترحة (الشعار والألوان والطباعة) بما يتفق مع أعمالنا.
#
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 5 - المنجزات المستهدفة:
#
# استخدام تقنيات الويب القياسية (HTML أو CSS أو JavaScript أو أطر عمل مثل React أو Vue.js أو CMS مثل WordPress إذا لزم الأمر).
#
# التوافق مع المتصفحات الرئيسية (Chrome، Firefox، Edge، Safari).
#
#
# أمن البيانات والامتثال RGPD.
#
#
# القيود غير التقنية.
#
#
# أفضل الممارسات في UX/ UI.
#
#
# قابلية التوسع لإضافة أقسام جديدة في تاريخ لاحق.
#
#
#
# </div>
