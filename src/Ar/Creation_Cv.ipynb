# %% [markdown]
# <div dir="rtl" align="right">
#
# # إنشاء السيرة الذاتية
#
# </div>
# ___
#
# ```{div} sd-sphinx-override sd-btn sd-text-wrap lang
# غير اللغة
# ```

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 1-مقدمة - نظرة عامة على المشروع
#
# يتعلق المشروع بإنشاء منصة عبر الإنترنت تتيح للمستخدمين تصميم وتخصيص ومشاركة سيرهم الذاتية بشكل احترافي. في سياق المنافسة المتزايدة في سوق العمل، من الضروري للمرشحين أن يتميزوا بسيرة ذاتية منظمة وجذابة. تهدف المنصة إلى تبسيط عملية إنشاء السيرة الذاتية من خلال تقديم أدوات سهلة الاستخدام ونماذج متنوعة.
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 2.	الفئة المستهدفة
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
# تستهدف المنصة بشكل رئيسي:
#
# -	**الباحثون عن عمل:** الأشخاص الذين يبحثون عن وظيفة ويرغبون في إنشاء سيرة ذاتية احترافية
#
# -	**الطلاب:** الطلاب الذين يسعون لدخول سوق العمل ويحتاجون إلى سيرة ذاتية لتقديم طلباتهم الأولى
#
# -	**المحترفون:** العاملون في إعادة التوجيه أو الذين يرغبون في تحديث سيرتهم الذاتية لفرص جديدة
#
# -	**المستقلون:** الأفراد الذين يحتاجون إلى سيرة ذاتية لتقديم مهاراتهم وخبراتهم للعملاء المحتملين
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 3.	الميزات الرئيسية
# -	نظام تسجيل دخول وتسجيل للمستخدمين.
# -	نماذج سيرة ذاتية قابلة للتخصيص ) تتضمن مجموعة من القوالب الجاهزة التي يمكن للمستخدمين اختيارها. )
# -	خيارات لإضافة أقسام (الخبرات، الشهادات، المهارات، إلخ).
# -	إنشاء رابط فريد لمشاركة السيرة الذاتية عبر الإنترنت.
# - 	خيار تحميل السيرة الذاتية بصيغة PDF.
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 4.	المخرجات
#
# في نهاية المشروع، نتوقع تسليم:
# -	**موقع ويب:** منصة عبر الإنترنت يمكن الوصول إليها من خلال المتصفح، تتيح للمستخدمين إنشاء وإدارة سيرهم الذاتية.
# -	**الهوية البصرية:** تصميم متسق وجذاب للمنصة، بما في ذلك الشعار، لوحة الألوان، والعناصر الرسومية.
#
# </div>

# %% [markdown]
# <div dir="rtl" align="right">
#
# ## 5.	القيود -اختيارية -
#
# -	ا**لتقنية:** يجب أن تكون المنصة متوافقة مع المتصفحات الرئيسية (Chrome ,Firefox..)  ومتجاوبة مع الأجهزة المحمولة.
# -	**الأمان:** يجب تأمين بيانات المستخدمين.
#
# </div>
